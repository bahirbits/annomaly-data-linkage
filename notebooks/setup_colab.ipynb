# %%
# !pwd
# Out:
# /content/annomaly-data-linkage

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
REPO_URL = "https://github.com/bahirbits/annomaly-data-linkage.git"
REPO_NAME = REPO_URL.split("/")[-1].replace(".git", "")
# !git clone $REPO_URL
# %cd $REPO_NAME
# Out:
# Cloning into 'annomaly-data-linkage'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 21 (delta 3), reused 17 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (21/21), 5.24 KiB | 2.62 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# /content/annomaly-data-linkage

# %%
import sys
sys.path.append('/content/REPO_NAME/notebooks')

# %%
# !git config --global user.email "ephe11ta@gmail.com"
# !git config --global user.name "ephremta"

# %%
# !git fetch --all
# Out:
# Fetching origin

# %%
# !git branch
# !git checkout dev
# Out:
# * main
# Branch 'dev' set up to track remote branch 'dev' from 'origin'.
# Switched to a new branch 'dev'

# %%
# Out:
# fatal: pathspec 'notebooks/setup-colab' did not match any files

# %%
# !find /content -name "setup-colab.ipynb"

# %%
# !mv /content/setup-colab.ipynb /content/annomaly-data-linkage/notebooks/
# Out:
# mv: cannot stat '/content/setup-colab.ipynb': No such file or directory

# %%
# !git add -A notebooks/setup-colab
